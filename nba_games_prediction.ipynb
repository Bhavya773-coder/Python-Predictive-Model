# %% [markdown]
# # Collect data

# %%
# %pip install nba_api
# Out:
# Requirement already satisfied: nba_api in d:\anaconda\lib\site-packages (1.5.2)
# Requirement already satisfied: certifi<2025.0.0,>=2023.7.22 in d:\anaconda\lib\site-packages (from nba_api) (2023.7.22)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in d:\anaconda\lib\site-packages (from nba_api) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.2 in d:\anaconda\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.31.2->nba_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.31.2->nba_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.31.2->nba_api) (1.26.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  \
# 0     42023  1610612742               DAL  Dallas Mavericks  0042300405
# 1     42023  1610612738               BOS    Boston Celtics  0042300405
# 2     42023  1610612742               DAL  Dallas Mavericks  0042300404
# 3     42023  1610612738               BOS    Boston Celtics  0042300404
# 4     42023  1610612738               BOS    Boston Celtics  0042300403
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2024-06-17    DAL @ BOS  L  240   88  ...   0.538     7    28   35   18
# 1  2024-06-17  BOS vs. DAL  W  240  106  ...   0.850    15    36   51   25
# 2  2024-06-14  DAL vs. BOS  W  240  122  ...   0.682    13    39   52   21
# 3  2024-06-14    BOS @ DAL  L  239   84  ...   0.923     4    27   31   18
# 4  2024-06-12    BOS @ DAL  W  240  106  ...   0.929     6    30   36   26
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    4    4   13  20       -18.0
# 1    9    2    7  15        18.0
# 2    7    2    8  17        38.0
# 3    2    5   13  19       -38.0
# 4    4    6    9  19         7.0
#
# [5 rows x 28 columns]

# %% [markdown]
# # Clean and Explore data

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                 TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  PLUS_MINUS
# 0        Dallas Mavericks  0042300405  2024-06-17    DAL @ BOS  L       -18.0
# 1          Boston Celtics  0042300405  2024-06-17  BOS vs. DAL  W        18.0
# 2        Dallas Mavericks  0042300404  2024-06-14  DAL vs. BOS  W        38.0
# 3          Boston Celtics  0042300404  2024-06-14    BOS @ DAL  L       -38.0
# 4          Boston Celtics  0042300403  2024-06-12    BOS @ DAL  W         7.0
# ...                   ...         ...         ...          ... ..         ...
# 11732     Houston Rockets  0021900722  2020-01-31  HOU vs. DAL  W         7.0
# 11733       Chicago Bulls  0021900721  2020-01-31    CHI @ BKN  L       -15.0
# 11734        Phoenix Suns  0021900725  2020-01-31  PHX vs. OKC  L        -4.0
# 11735      Denver Nuggets  0021900724  2020-01-31    DEN @ MIL  W        12.0
# 11736  Los Angeles Lakers  0021900726  2020-01-31  LAL vs. POR  L        -8.0
#
# [11737 rows x 6 columns]

# %% [markdown]
# final DataFrame: two columns: 1.result of game: target 2.score statistics comparing two teams: feature

# %%
import pandas as pd

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11737 entries, 0 to 11736
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   11737 non-null  object
#  1   GAME_ID     11737 non-null  object
#  2   GAME_DATE   11737 non-null  object
#  3   MATCHUP     11737 non-null  object
#  4   WL          11736 non-null  object
#  5   PLUS_MINUS  11737 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 550.3+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0       2024-06-17
# 1       2024-06-17
# 2       2024-06-14
# 3       2024-06-14
# 4       2024-06-12
#            ...
# 11732   2020-01-31
# 11733   2020-01-31
# 11734   2020-01-31
# 11735   2020-01-31
# 11736   2020-01-31
# Name: GAME_DATE, Length: 11737, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')
games
# Out:
#                     TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 11736      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# 11723  Portland Trail Blazers  0021900726 2020-01-31    POR @ LAL  W
# 11724         Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# 11725       Memphis Grizzlies  0021900723 2020-01-31    MEM @ NOP  L
# 11726         Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W
# ...                       ...         ...        ...          ... ..
# 4              Boston Celtics  0042300403 2024-06-12    BOS @ DAL  W
# 3              Boston Celtics  0042300404 2024-06-14    BOS @ DAL  L
# 2            Dallas Mavericks  0042300404 2024-06-14  DAL vs. BOS  W
# 1              Boston Celtics  0042300405 2024-06-17  BOS vs. DAL  W
# 0            Dallas Mavericks  0042300405 2024-06-17    DAL @ BOS  L
#
#        PLUS_MINUS
# 11736        -8.0
# 11723         8.0
# 11724       -12.0
# 11725       -28.0
# 11726        13.0
# ...           ...
# 4             7.0
# 3           -38.0
# 2            38.0
# 1            18.0
# 0           -18.0
#
# [11737 rows x 6 columns]

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games
# Out:
#                     TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 11736      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# 11723  Portland Trail Blazers  0021900726 2020-01-31    POR @ LAL  W
# 11724         Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# 11725       Memphis Grizzlies  0021900723 2020-01-31    MEM @ NOP  L
# 11726         Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W
# ...                       ...         ...        ...          ... ..
# 4              Boston Celtics  0042300403 2024-06-12    BOS @ DAL  W
# 3              Boston Celtics  0042300404 2024-06-14    BOS @ DAL  L
# 2            Dallas Mavericks  0042300404 2024-06-14  DAL vs. BOS  W
# 1              Boston Celtics  0042300405 2024-06-17  BOS vs. DAL  W
# 0            Dallas Mavericks  0042300405 2024-06-17    DAL @ BOS  L
#
#        PLUS_MINUS  avg_30_plus_minus
# 11736        -8.0                NaN
# 11723         8.0                NaN
# 11724       -12.0                NaN
# 11725       -28.0                NaN
# 11726        13.0                NaN
# ...           ...                ...
# 4             7.0          10.133333
# 3           -38.0          10.266667
# 2            38.0           2.000000
# 1            18.0           8.100000
# 0           -18.0           3.133333
#
# [11737 rows x 7 columns]

# %%
games[games['TEAM_NAME']=='Toronto Raptors'].head(35)
# Out:
#              TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 11726  Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# 11702  Toronto Raptors  0021900740 2020-02-02  TOR vs. CHI  W        27.0
# 11665  Toronto Raptors  0021900758 2020-02-05  TOR vs. IND  W         1.0
# 11633  Toronto Raptors  0021900772 2020-02-07    TOR @ IND  W         9.0
# 11612  Toronto Raptors  0021900781 2020-02-08  TOR vs. BKN  W         1.0
# 11587  Toronto Raptors  0021900796 2020-02-10  TOR vs. MIN  W        11.0
# 11543  Toronto Raptors  0021900809 2020-02-12    TOR @ BKN  L       -10.0
# 11513  Toronto Raptors  0021900829 2020-02-21  TOR vs. PHX  W        17.0
# 11474  Toronto Raptors  0021900843 2020-02-23  TOR vs. IND  W        46.0
# 11444  Toronto Raptors  0021900858 2020-02-25  TOR vs. MIL  L       -11.0
# 11407  Toronto Raptors  0021900879 2020-02-28  TOR vs. CHA  L        -3.0
# 11369  Toronto Raptors  0021900898 2020-03-01    TOR @ DEN  L       -15.0
# 11352  Toronto Raptors  0021900914 2020-03-03    TOR @ PHX  W         9.0
# 11314  Toronto Raptors  0021900929 2020-03-05    TOR @ GSW  W         8.0
# 11270  Toronto Raptors  0021900956 2020-03-08    TOR @ SAC  W         5.0
# 11251  Toronto Raptors  0021900959 2020-03-09    TOR @ UTA  W         9.0
# 11206  Toronto Raptors  0011900111 2020-07-24  TOR vs. HOU  W        11.0
# 11184  Toronto Raptors  0011900121 2020-07-26  TOR vs. POR  W         6.0
# 11169  Toronto Raptors  0011900129 2020-07-28    TOR @ PHX  L       -11.0
# 11138  Toronto Raptors  0021901243 2020-08-01  TOR vs. LAL  W        15.0
# 11110  Toronto Raptors  0021901250 2020-08-03    TOR @ MIA  W         4.0
# 11095  Toronto Raptors  0021901266 2020-08-05    TOR @ ORL  W        10.0
# 11072  Toronto Raptors  0021901279 2020-08-07  TOR vs. BOS  L       -22.0
# 11046  Toronto Raptors  0021901286 2020-08-09  TOR vs. MEM  W         9.0
# 11032  Toronto Raptors  0021901294 2020-08-10    TOR @ MIL  W         8.0
# 11010  Toronto Raptors  0021901305 2020-08-12    TOR @ PHI  W         4.0
# 10988  Toronto Raptors  0021901318 2020-08-14  TOR vs. DEN  W         8.0
# 10979  Toronto Raptors  0041900111 2020-08-17  TOR vs. BKN  W        24.0
# 10957  Toronto Raptors  0041900112 2020-08-19  TOR vs. BKN  W         5.0
# 10948  Toronto Raptors  0041900113 2020-08-21    TOR @ BKN  W        25.0
# 10926  Toronto Raptors  0041900114 2020-08-23    TOR @ BKN  W        28.0
# 10906  Toronto Raptors  0041900211 2020-08-30  TOR vs. BOS  L       -18.0
# 10893  Toronto Raptors  0041900212 2020-09-01  TOR vs. BOS  L        -3.0
# 10887  Toronto Raptors  0041900213 2020-09-03    TOR @ BOS  W         1.0
# 10877  Toronto Raptors  0041900214 2020-09-05    TOR @ BOS  W         7.0
#
#        avg_30_plus_minus
# 11726                NaN
# 11702                NaN
# 11665                NaN
# 11633                NaN
# 11612                NaN
# 11587                NaN
# 11543                NaN
# 11513                NaN
# 11474                NaN
# 11444                NaN
# 11407                NaN
# 11369                NaN
# 11352                NaN
# 11314                NaN
# 11270                NaN
# 11251                NaN
# 11206                NaN
# 11184                NaN
# 11169                NaN
# 11138                NaN
# 11110                NaN
# 11095                NaN
# 11072                NaN
# 11046                NaN
# 11032                NaN
# 11010                NaN
# 10988                NaN
# 10979                NaN
# 10957                NaN
# 10948                NaN
# 10926           7.100000
# 10906           7.600000
# 10893           6.100000
# 10887           5.966667
# 10877           5.700000

# %%
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (5869, 7)

# %%
games_away.shape
# Out:
# (5868, 7)

# %%
games_home
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 11736    Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# 11724       Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# 11728         Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W
# 11731  New Orleans Pelicans  0021900723 2020-01-31  NOP vs. MEM  W
# 11732       Houston Rockets  0021900722 2020-01-31  HOU vs. DAL  W
# ...                     ...         ...        ...          ... ..
# 8            Boston Celtics  0042300401 2024-06-06  BOS vs. DAL  W
# 6            Boston Celtics  0042300402 2024-06-09  BOS vs. DAL  W
# 5          Dallas Mavericks  0042300403 2024-06-12  DAL vs. BOS  L
# 2          Dallas Mavericks  0042300404 2024-06-14  DAL vs. BOS  W
# 1            Boston Celtics  0042300405 2024-06-17  BOS vs. DAL  W
#
#        PLUS_MINUS  avg_30_plus_minus
# 11736        -8.0                NaN
# 11724       -12.0                NaN
# 11728        15.0                NaN
# 11731        28.0                NaN
# 11732         7.0                NaN
# ...           ...                ...
# 8            18.0          11.000000
# 6             7.0          10.733333
# 5            -7.0           3.433333
# 2            38.0           2.000000
# 1            18.0           8.100000
#
# [5869 rows x 7 columns]

# %%
games_away
# Out:
#                     TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  \
# 11723  Portland Trail Blazers  0021900726 2020-01-31  POR @ LAL  W
# 11725       Memphis Grizzlies  0021900723 2020-01-31  MEM @ NOP  L
# 11726         Toronto Raptors  0021900720 2020-01-31  TOR @ DET  W
# 11727   Oklahoma City Thunder  0021900725 2020-01-31  OKC @ PHX  W
# 11735          Denver Nuggets  0021900724 2020-01-31  DEN @ MIL  W
# ...                       ...         ...        ...        ... ..
# 9            Dallas Mavericks  0042300401 2024-06-06  DAL @ BOS  L
# 7            Dallas Mavericks  0042300402 2024-06-09  DAL @ BOS  L
# 4              Boston Celtics  0042300403 2024-06-12  BOS @ DAL  W
# 3              Boston Celtics  0042300404 2024-06-14  BOS @ DAL  L
# 0            Dallas Mavericks  0042300405 2024-06-17  DAL @ BOS  L
#
#        PLUS_MINUS  avg_30_plus_minus
# 11723         8.0                NaN
# 11725       -28.0                NaN
# 11726        13.0                NaN
# 11727         4.0                NaN
# 11735        12.0                NaN
# ...           ...                ...
# 9           -18.0           5.133333
# 7            -7.0           4.000000
# 4             7.0          10.133333
# 3           -38.0          10.266667
# 0           -18.0           3.133333
#
# [5868 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))
games_merged
# Out:
#             TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0       Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 1          Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 2            Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3     New Orleans Pelicans  0021900723     2020-01-31  NOP vs. MEM       W
# 4          Houston Rockets  0021900722     2020-01-31  HOU vs. DAL       W
# ...                    ...         ...            ...          ...     ...
# 5864        Boston Celtics  0042300401     2024-06-06  BOS vs. DAL       W
# 5865        Boston Celtics  0042300402     2024-06-09  BOS vs. DAL       W
# 5866      Dallas Mavericks  0042300403     2024-06-12  DAL vs. BOS       L
# 5867      Dallas Mavericks  0042300404     2024-06-14  DAL vs. BOS       W
# 5868        Boston Celtics  0042300405     2024-06-17  BOS vs. DAL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                -8.0                     NaN  Portland Trail Blazers
# 1               -12.0                     NaN          Denver Nuggets
# 2                15.0                     NaN           Chicago Bulls
# 3                28.0                     NaN       Memphis Grizzlies
# 4                 7.0                     NaN        Dallas Mavericks
# ...               ...                     ...                     ...
# 5864             18.0               11.000000        Dallas Mavericks
# 5865              7.0               10.733333        Dallas Mavericks
# 5866             -7.0                3.433333          Boston Celtics
# 5867             38.0                2.000000          Boston Celtics
# 5868             18.0                8.100000        Dallas Mavericks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    POR @ LAL       W              8.0
# 1        2020-01-31    DEN @ MIL       W             12.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    MEM @ NOP       L            -28.0
# 4        2020-01-31    DAL @ HOU       L             -7.0
# ...             ...          ...     ...              ...
# 5864     2024-06-06    DAL @ BOS       L            -18.0
# 5865     2024-06-09    DAL @ BOS       L             -7.0
# 5866     2024-06-12    BOS @ DAL       W              7.0
# 5867     2024-06-14    BOS @ DAL       L            -38.0
# 5868     2024-06-17    DAL @ BOS       L            -18.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 5864                5.133333
# 5865                4.000000
# 5866               10.133333
# 5867               10.266667
# 5868                3.133333
#
# [5869 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#             TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0       Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 1          Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 2            Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3     New Orleans Pelicans  0021900723     2020-01-31  NOP vs. MEM       W
# 4          Houston Rockets  0021900722     2020-01-31  HOU vs. DAL       W
# ...                    ...         ...            ...          ...     ...
# 5864        Boston Celtics  0042300401     2024-06-06  BOS vs. DAL       W
# 5865        Boston Celtics  0042300402     2024-06-09  BOS vs. DAL       W
# 5866      Dallas Mavericks  0042300403     2024-06-12  DAL vs. BOS       L
# 5867      Dallas Mavericks  0042300404     2024-06-14  DAL vs. BOS       W
# 5868        Boston Celtics  0042300405     2024-06-17  BOS vs. DAL       W
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                -8.0                     NaN  Portland Trail Blazers
# 1               -12.0                     NaN          Denver Nuggets
# 2                15.0                     NaN           Chicago Bulls
# 3                28.0                     NaN       Memphis Grizzlies
# 4                 7.0                     NaN        Dallas Mavericks
# ...               ...                     ...                     ...
# 5864             18.0               11.000000        Dallas Mavericks
# 5865              7.0               10.733333        Dallas Mavericks
# 5866             -7.0                3.433333          Boston Celtics
# 5867             38.0                2.000000          Boston Celtics
# 5868             18.0                8.100000        Dallas Mavericks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    POR @ LAL       W              8.0
# 1        2020-01-31    DEN @ MIL       W             12.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    MEM @ NOP       L            -28.0
# 4        2020-01-31    DAL @ HOU       L             -7.0
# ...             ...          ...     ...              ...
# 5864     2024-06-06    DAL @ BOS       L            -18.0
# 5865     2024-06-09    DAL @ BOS       L             -7.0
# 5866     2024-06-12    BOS @ DAL       W              7.0
# 5867     2024-06-14    BOS @ DAL       L            -38.0
# 5868     2024-06-17    DAL @ BOS       L            -18.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 5864                5.133333                5.866667
# 5865                4.000000                6.733333
# 5866               10.133333               -6.700000
# 5867               10.266667               -8.266667
# 5868                3.133333                4.966667
#
# [5869 rows x 14 columns]

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          L                     NaN
# 1          L                     NaN
# 2          W                     NaN
# 3          W                     NaN
# 4          W                     NaN
# ...      ...                     ...
# 5864       W                5.866667
# 5865       W                6.733333
# 5866       L               -6.700000
# 5867       W               -8.266667
# 5868       W                4.966667
#
# [5869 rows x 2 columns]

# %%
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 398        L               -6.233333
# 400        L               -5.366667
# 401        W                1.933333
# 402        L               -5.600000
# 403        W                2.466667
# ...      ...                     ...
# 5864       W                5.866667
# 5865       W                6.733333
# 5866       L               -6.700000
# 5867       W               -8.266667
# 5868       W                4.966667
#
# [5336 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 398         0               -6.233333
# 400         0               -5.366667
# 401         1                1.933333
# 402         0               -5.600000
# 403         1                2.466667
# ...       ...                     ...
# 5864        1                5.866667
# 5865        1                6.733333
# 5866        0               -6.700000
# 5867        1               -8.266667
# 5868        1                4.966667
#
# [5336 rows x 2 columns]

# %% [markdown]
# # Build the predictive model, hyperparameter tuning, evaluation

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (4268, 2)

# %%
df_test.shape
# Out:
# (1068, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %%
 # %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in d:\anaconda\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from xgboost) (1.11.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
clf = xgb.XGBClassifier( random_state=7)

# %%
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=7, ...)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5973782771535581

# %%
pip install  scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in d:\anaconda\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
from scipy.stats import loguniform

# %%
hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=clf, 
                                param_distributions=hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=7, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000240DAE7EE10>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.025246179740589205,
#  'max_depth': 2,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
accuracy_score(y_test, y_pred_hyp)
# Out:
# 0.6254681647940075

# %% [markdown]
# # Deploy the model with FastAPI

# %%
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6254681647940075

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]

games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

import pandas as pd

games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

games = games.sort_values('GAME_DATE')

games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
team_home='Toronto Raptors'
team_away='Boston Celtics'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2021',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]

# %%
def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='01/01/2021',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Boston Celtics','Toronto Raptors')
# Out:
# (1, 0.8330254)

# %%
pip install fastapi
# Out:
# Requirement already satisfied: fastapi in d:\anaconda\lib\site-packages (0.115.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in d:\anaconda\lib\site-packages (from fastapi) (0.38.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in d:\anaconda\lib\site-packages (from fastapi) (1.10.8)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\anaconda\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in d:\anaconda\lib\site-packages (from starlette<0.39.0,>=0.37.2->fastapi) (3.5.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.39.0,>=0.37.2->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.39.0,>=0.37.2->fastapi) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "fastapi[standard]"
# Out:
# Requirement already satisfied: fastapi[standard] in d:\anaconda\lib\site-packages (0.115.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in d:\anaconda\lib\site-packages (from fastapi[standard]) (0.38.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in d:\anaconda\lib\site-packages (from fastapi[standard]) (1.10.8)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\anaconda\lib\site-packages (from fastapi[standard]) (4.12.2)
# Collecting fastapi-cli[standard]>=0.0.5 (from fastapi[standard])
#   Obtaining dependency information for fastapi-cli[standard]>=0.0.5 from https://files.pythonhosted.org/packages/24/ea/4b5011012ac925fe2f83b19d0e09cee9d324141ec7bf5e78bb2817f96513/fastapi_cli-0.0.5-py3-none-any.whl.metadata
#   Downloading fastapi_cli-0.0.5-py3-none-any.whl.metadata (7.0 kB)
# Collecting httpx>=0.23.0 (from fastapi[standard])
#   Obtaining dependency information for httpx>=0.23.0 from https://files.pythonhosted.org/packages/56/95/9377bcb415797e44274b51d46e3249eba641711cf3348050f76ee7b15ffc/httpx-0.27.2-py3-none-any.whl.metadata
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2>=2.11.2 in d:\anaconda\lib\site-packages (from fastapi[standard]) (3.1.2)
# Collecting python-multipart>=0.0.7 (from fastapi[standard])
#   Obtaining dependency information for python-multipart>=0.0.7 from https://files.pythonhosted.org/packages/b8/d7/1d8acecc4621aa2b70fca28c1a651e02d936152e77d6be07d00601b31cf3/python_multipart-0.0.10-py3-none-any.whl.metadata
#   Downloading python_multipart-0.0.10-py3-none-any.whl.metadata (1.9 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Obtaining dependency information for email-validator>=2.0.0 from https://files.pythonhosted.org/packages/d7/ee/bf0adb559ad3c786f12bcbc9296b3f5675f529199bef03e2df281fa1fadb/email_validator-2.2.0-py3-none-any.whl.metadata
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn[standard]>=0.12.0 (from fastapi[standard])
#   Obtaining dependency information for uvicorn[standard]>=0.12.0 from https://files.pythonhosted.org/packages/f5/8e/cdc7d6263db313030e4c257dd5ba3909ebc4e4fb53ad62d5f09b1a2f5458/uvicorn-0.30.6-py3-none-any.whl.metadata
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard])
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in d:\anaconda\lib\site-packages (from email-validator>=2.0.0->fastapi[standard]) (3.4)
# Collecting typer>=0.12.3 (from fastapi-cli[standard]>=0.0.5->fastapi[standard])
#   Obtaining dependency information for typer>=0.12.3 from https://files.pythonhosted.org/packages/a8/2b/886d13e742e514f704c33c4caa7df0f3b89e5a25ef8db02aa9ca3d9535d5/typer-0.12.5-py3-none-any.whl.metadata
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx>=0.23.0->fastapi[standard]) (3.5.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx>=0.23.0->fastapi[standard]) (2023.7.22)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi[standard])
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/78/d4/e5d7e4f2174f8a4d63c8897d79eb8fe2503f7ecc03282fee1fa2719c2704/httpcore-1.0.5-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from httpx>=0.23.0->fastapi[standard]) (1.2.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->fastapi[standard])
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2>=2.11.2->fastapi[standard]) (2.1.1)
# Requirement already satisfied: click>=7.0 in d:\anaconda\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]) (8.0.4)
# Requirement already satisfied: colorama>=0.4 in d:\anaconda\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]) (0.4.6)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi[standard])
#   Obtaining dependency information for httptools>=0.5.0 from https://files.pythonhosted.org/packages/14/e4/20d28dfe7f5b5603b6b04c33bb88662ad749de51f0c539a561f235f42666/httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in d:\anaconda\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]) (0.21.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi[standard]) (6.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi[standard])
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/8a/8b/badd9247d6ec25f5f634a9b3d0d92e39c045824ec7e8afcedca8ee52c1e2/watchfiles-0.24.0-cp311-none-win_amd64.whl.metadata
#   Downloading watchfiles-0.24.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi[standard])
#   Obtaining dependency information for websockets>=10.4 from https://files.pythonhosted.org/packages/fb/39/ec8832ecb9bb04a8d318149005ed8cee0ba4e0205835da99e0aa497a091f/websockets-13.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading websockets-13.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard])
#   Obtaining dependency information for shellingham>=1.3.0 from https://files.pythonhosted.org/packages/e0/f9/0595336914c5619e5f28a1fb793285925a8cd4b432c9da0a987836c7f822/shellingham-1.5.4-py2.py3-none-any.whl.metadata
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard])
#   Obtaining dependency information for rich>=10.11.0 from https://files.pythonhosted.org/packages/b0/11/dadb85e2bd6b1f1ae56669c3e1f0410797f9605d752d68fb47b77f525b31/rich-13.8.1-py3-none-any.whl.metadata
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard]) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli[standard]>=0.0.5->fastapi[standard]) (0.1.0)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB 2.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 2.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.10-py3-none-any.whl (22 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/307.7 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 3.8 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp311-cp311-win_amd64.whl (55 kB)
#    ---------------------------------------- 0.0/55.4 kB ? eta -:--:--
#    ---------------------------------------- 55.4/55.4 kB 2.8 MB/s eta 0:00:00
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    ---------------------------------------- 47.3/47.3 kB 2.5 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp311-none-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.5 kB ? eta -:--:--
#    ---------------- ----------------------- 112.6/277.5 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  276.5/277.5 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 277.5/277.5 kB 2.8 MB/s eta 0:00:00
# Downloading websockets-13.1-cp311-cp311-win_amd64.whl (159 kB)
#    ---------------------------------------- 0.0/159.1 kB ? eta -:--:--
#    ---------------------------------------- 159.1/159.1 kB 4.8 MB/s eta 0:00:00
# Downloading fastapi_cli-0.0.5-py3-none-any.whl (9.5 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB 3.3 MB/s eta 0:00:00
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
#    ---------------------------------------- 0.0/241.6 kB ? eta -:--:--
#    ----------------------- ---------------- 143.4/241.6 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 241.6/241.6 kB 3.0 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: websockets, shellingham, python-multipart, httptools, h11, dnspython, watchfiles, uvicorn, rich, httpcore, email-validator, typer, httpx, fastapi-cli
# Successfully installed dnspython-2.6.1 email-validator-2.2.0 fastapi-cli-0.0.5 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.2 python-multipart-0.0.10 rich-13.8.1 shellingham-1.5.4 typer-0.12.5 uvicorn-0.30.6 watchfiles-0.24.0 websockets-13.1
# Note: you may need to restart the kernel to use updated packages.
